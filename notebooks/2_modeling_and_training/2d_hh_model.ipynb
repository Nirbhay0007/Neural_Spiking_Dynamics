# %%
using  JLD2 , ComponentArrays
l = @load("UDE_2D_HH_best_params.jld2")
# Out:
# 3-element Vector{Symbol}:
#  :params
#  :loss_history
#  :best_loss

# %%
using  JLD2 , ComponentArrays
l3 = @load("Data/synthetic_data/noise_05_hh_2d_model.jld")
# Out:
# 1-element Vector{Symbol}:
#  :t

# %%
plot(t)

# %%
using Plots
plot(loss_history)

# %%
data=@load raw"C:\Users\nirbh\Neural_Spiking_Dynamics\Data\synthetic_data\noise_05_hh_2d_model.jld2"
# Out:
# LoadError: ArgumentError: filename argument must be a string literal unless variable names are specified
#
# in expression starting at c:\Users\nirbh\Neural_Spiking_Dynamics\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X10sZmlsZQ==.jl:1
#
#
#
# Stacktrace:
#
#   [1] var"@load"(__source__::LineNumberNode, __module__::Module, filename::Any, vars::Vararg{Any})
#
#     @ JLD2 C:\Users\nirbh\.julia\packages\JLD2\hbsZG\src\loadsave.jl:136
#
#   [2] eval
#
#     @ .\boot.jl:430 [inlined]
#
#   [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:2734
#
#   [4] #invokelatest#2
#
#     @ .\essentials.jl:1055 [inlined]
#
#   [5] invokelatest
#
#     @ .\essentials.jl:1052 [inlined]
#
#   [6] (::VSCodeServer.var"#220#221"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\nirbh\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#
#   [7] withpath(f::VSCodeServer.var"#220#221"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\nirbh\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\repl.jl:278
#
#   [8] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer c:\Users\nirbh\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#   [9] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC c:\Users\nirbh\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\JSONRPC\src\typed.jl:68
#
#  [10] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#9#14"{String})
#
#     @ VSCodeServer c:\Users\nirbh\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#
#  [11] top-level scope
#
#     @ c:\Users\nirbh\.vscode\extensions\julialang.language-julia-1.170.2\scripts\notebook\notebook.jl:28

# %%
using JLD2

# %%
# Physics Constants (Explicit Float32)
const Cm  = 1.0f0      # µF/cm²
const g_Na = 120.0f0    # mS/cm²
const E_Na = 50.0f0     # mV
const g_L  = 0.3f0      # mS/cm²
const E_L  = -54.387f0  # mV
const g_K  = 36.0f0    #potassium conductance (mS/cm²)
const E_K  = -77.0f0 
# Voltage-gated ion channel kinetics (Float32)

α_n(V::Float32) = 0.01f0 * (V + 55f0) / (1f0 - exp(-(V + 55f0) / 10f0))
β_n(V::Float32) = 0.125f0 * exp(-(V + 65f0) / 80f0)

α_m(V::Float32) = 0.1f0 * (V + 40f0) / (1f0 - exp(-(V + 40f0) / 10f0))
β_m(V::Float32) = 4.0f0 * exp(-(V + 65f0) / 18f0)

α_h(V::Float32) = 0.07f0 * exp(-(V + 65f0) / 20f0)
β_h(V::Float32) = 1f0 / (1f0 + exp(-(V + 35f0) / 10f0))

# Steady-state & time-constant functions (Float32)

m_inf(V::Float32) = α_m(V) / (α_m(V) + β_m(V))
h_inf(V::Float32) = α_h(V) / (α_h(V) + β_h(V))
n_inf(V::Float32) = α_n(V) / (α_n(V) + β_n(V))

tau_n(V::Float32) = 1f0 / (α_n(V) + β_n(V))

println("Physics of neural dynamics defined in Float32")
# Out:
# Physics of neural dynamics defined in Float32

# %%
using SciMLSensitivity, DifferentialEquations, ModelingToolkit, Optimization, OptimizationOptimisers
using Lux, Random, ComponentArrays, CUDA, Zygote
using Plots, JLD2

# 1. SETUP & DATA (Move to GPU)
# ------------------------------------------------
@load "Data/synthetic_data/noise_0_hh_2d_model.jld" V
t_train = 0.0f0:0.1f0:50.0f0

# Move data to GPU
V_gpu = cu(Float32.(V))
t_train_gpu = cu(t_train)
# Also keep a CPU copy of V for safe CPU-side loss computation
V_cpu = Array(V_gpu)

# 2. DEFINE MODEL WITH LUX (The Modern Way)
# ------------------------------------------------
# Lux models are explicit. We don't 'destructure' them.
# We define the structure once.
nn = Lux.Chain(
    Lux.Dense(1, 16, tanh),
    Lux.Dense(16, 1)
)

# Initialize parameters (p) and state (st)
rng = Random.default_rng()
p_init, st = Lux.setup(rng, nn)

# CRITICAL STABILITY FIX
# Set final layer weights to zero to prevent initial explosion
p_init.layer_2.weight .= 0.0f0
p_init.layer_2.bias   .= 0.0f0

# Move parameters to GPU
p_gpu = cu(ComponentArray(p_init))
st_gpu = cu(st) # State also needs to be on GPU

# External stimulus function (simple square pulse). Replace with your experiment's stimulus as needed.
function Stimulus(t)
    return (t >= 10.0f0 && t < 11.0f0) ? 20.0f0 : 0.0f0
end

# 3. UDE FUNCTION (Optimized for GPU)
# ------------------------------------------------
# We pass the Lux model structure 'nn' and state 'st' via a closure or global
function hodgkin_huxley_UDE!(du, u, p, t, nn, st)
    # Avoid scalar indexing on a CuArray `u` (disallowed on GPU).
    # Copy the small state vector to CPU and work with it instead.
    u_local = Array(u)
    V, n = u_local
    
    # LUX FORWARD PASS
    # Run the NN on GPU (parameters `p`/`st` are on GPU) but keep physics on CPU scalars.
    _V_input_gpu = cu(Float32[V])
    pred_gpu, _ = nn(_V_input_gpu, p, st)
    pred_cpu = Array(pred_gpu)
    pred_I_Na = pred_cpu[1]
    
    # Physics calculations on CPU scalars
    I_ext = Stimulus(t)
    I_K = g_K * n^4 * (V - E_K)
    I_L = g_L * (V - E_L)
    du_local1 = (I_ext - (pred_I_Na + I_K + I_L) / Cm)
    du_local2 = (n_inf(V) - n) / tau_n(V)
    
    # Transfer derivatives back to GPU `du`
    du .= cu(Float32[du_local1, du_local2])
end

# 4. WRAPPER FOR SCIML
# ------------------------------------------------
# DifferentialEquations expects (du, u, p, t)
# We wrap the Lux model and state into the function
ude_dynamics!(du, u, p, t) = hodgkin_huxley_UDE!(du, u, p, t, nn, st_gpu)

u0_gpu = cu([-65.0f0, 0.317f0])
prob_nn = ODEProblem(ude_dynamics!, u0_gpu, (0.0f0, 50.0f0), p_gpu)

# 5. SOLVE (Using a GPU-friendly solver)
# ------------------------------------------------
function loss(p)
    # GBS (Grossmann-Bulirsch-Stoer) is often robust for simple problems
    # Tsit5 is standard. 
    pred = solve(prob_nn, Tsit5(), p=p, saveat=t_train_gpu, 
                 reltol=1e-4, abstol=1e-4) # Lower tolerance for Float32
    
    if pred.retcode != :Success
        return 1f6
    end
    
    # Vectorized GPU loss calculation (compute on CPU to avoid scalar GPU indexing)
    pred_arr = Array(pred)  # materialize solution on CPU
    loss_val = sum(abs2, pred_arr[1,:] .- V_cpu)
    return loss_val
end

# ... Optimization follows ...
optf = Optimization.OptimizationFunction((x, p) -> loss(x), Optimization.AutoZygote())
optprob = Optimization.OptimizationProblem(optf, p_gpu) # Pass GPU parameters

res = Optimization.solve(optprob, OptimizationOptimisers.Adam(0.01), maxiters=1000)
# Out:
# GPU compilation of MethodInstance for (::GPUArrays.var"#gpu_broadcast_kernel_linear#39")(::KernelAbstractions.CompilerMetadata{KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.DynamicCheck, Nothing, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, KernelAbstractions.NDIteration.NDRange{1, KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.DynamicSize, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}}}, ::CuDeviceVector{Float32, 1}, ::Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{1, CUDA.DeviceMemory}, Tuple{Base.OneTo{Int64}}, typeof(-), Tuple{Base.Broadcast.Extruded{CuDeviceVector{Float32, 1}, Tuple{Bool}, Tuple{Int64}}, Base.Broadcast.Extruded{Vector{Float32}, Tuple{Bool}, Tuple{Int64}}}}) failed
#
# KernelError: passing non-bitstype argument
#
#
#
# Argument 4 to your kernel function is of type Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{1, CUDA.DeviceMemory}, Tuple{Base.OneTo{Int64}}, typeof(-), Tuple{Base.Broadcast.Extruded{CuDeviceVector{Float32, 1}, Tuple{Bool}, Tuple{Int64}}, Base.Broadcast.Extruded{Vector{Float32}, Tuple{Bool}, Tuple{Int64}}}}, which is not a bitstype:
#
#   .args is of type Tuple{Base.Broadcast.Extruded{CuDeviceVector{Float32, 1}, Tuple{Bool}, Tuple{Int64}}, Base.Broadcast.Extruded{Vector{Float32}, Tuple{Bool}, Tuple{Int64}}} which is not isbits.
#
#     .2 is of type Base.Broadcast.Extruded{Vector{Float32}, Tuple{Bool}, Tuple{Int64}} which is not isbits.
#
#       .x is of type Vector{Float32} which is not isbits.
#
#         .ref is of type MemoryRef{Float32} which is not isbits.
#
#           .mem is of type Memory{Float32} which is not isbits.
#
#
#
#
#
# Only bitstypes, which are "plain data" types that are immutable
#
# and contain no references to other values, can be used in GPU kernels.
#
# For more information, see the `Base.isbitstype` function.
#
#
#
#
#
# Stacktrace:
#
#   [1] check_invocation(job::GPUCompiler.CompilerJob)
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\validation.jl:108
#
#   [2] compile_unhooked(output::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\driver.jl:87
#
#   [3] compile_unhooked(output::Symbol, job::GPUCompiler.CompilerJob)
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\driver.jl:80
#
#   [4] compile(target::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\driver.jl:67
#
#   [5] compile
#
#     @ C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\driver.jl:55 [inlined]
#
#   [6] #1188
#
#     @ C:\Users\Admin\.julia\packages\CUDA\x8d2s\src\compiler\compilation.jl:250 [inlined]
#
#   [7] JuliaContext(f::CUDA.var"#1188#1191"{GPUCompiler.CompilerJob{GPUCompiler.PTXCompilerTarget, CUDA.CUDACompilerParams}}; kwargs::@Kwargs{})
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\driver.jl:34
#
#   [8] JuliaContext(f::Function)
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\driver.jl:25
#
#   [9] compile(job::GPUCompiler.CompilerJob)
#
#     @ CUDA C:\Users\Admin\.julia\packages\CUDA\x8d2s\src\compiler\compilation.jl:249
#
#  [10] actual_compilation(cache::Dict{Any, CuFunction}, src::Core.MethodInstance, world::UInt64, cfg::GPUCompiler.CompilerConfig{GPUCompiler.PTXCompilerTarget, CUDA.CUDACompilerParams}, compiler::typeof(CUDA.compile), linker::typeof(CUDA.link))
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\execution.jl:245
#
#  [11] cached_compilation(cache::Dict{Any, CuFunction}, src::Core.MethodInstance, cfg::GPUCompiler.CompilerConfig{GPUCompiler.PTXCompilerTarget, CUDA.CUDACompilerParams}, compiler::Function, linker::Function)
#
#     @ GPUCompiler C:\Users\Admin\.julia\packages\GPUCompiler\j4HFa\src\execution.jl:159
#
#  [12] macro expansion
#
#     @ C:\Users\Admin\.julia\packages\CUDA\x8d2s\src\compiler\execution.jl:373 [inlined]
#
#  [13] macro expansion
#
#     @ .\lock.jl:273 [inlined]
#
#  [14] cufunction(f::GPUArrays.var"#gpu_broadcast_kernel_linear#39", tt::Type{Tuple{KernelAbstractions.CompilerMetadata{KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.DynamicCheck, Nothing, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, KernelAbstractions.NDIteration.NDRange{1, KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.DynamicSize, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}}}, CuDeviceVector{Float32, 1}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{1, CUDA.DeviceMemory}, Tuple{Base.OneTo{Int64}}, typeof(-), Tuple{Base.Broadcast.Extruded{CuDeviceVector{Float32, 1}, Tuple{Bool}, Tuple{Int64}}, Base.Broadcast.Extruded{Vector{Float32}, Tuple{Bool}, Tuple{Int64}}}}}}; kwargs::@Kwargs{always_inline::Bool, maxthreads::Nothing})
#
#     @ CUDA C:\Users\Admin\.julia\packages\CUDA\x8d2s\src\compiler\execution.jl:368
#
#  [15] macro expansion
#
#     @ C:\Users\Admin\.julia\packages\CUDA\x8d2s\src\compiler\execution.jl:112 [inlined]
#
#  [16] (::KernelAbstractions.Kernel{CUDABackend, KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.DynamicSize, GPUArrays.var"#gpu_broadcast_kernel_linear#39"})(::CuArray{Float32, 1, CUDA.DeviceMemory}, ::Vararg{Any}; ndrange::Tuple{Int64}, workgroupsize::Nothing)
#
#     @ CUDA.CUDAKernels C:\Users\Admin\.julia\packages\CUDA\x8d2s\src\CUDAKernels.jl:127
#
#  [17] Kernel
#
#     @ C:\Users\Admin\.julia\packages\CUDA\x8d2s\src\CUDAKernels.jl:113 [inlined]
#
#  [18] _copyto!
#
#     @ C:\Users\Admin\.julia\packages\GPUArrays\0F4Dn\src\host\broadcast.jl:71 [inlined]
#
#  [19] copyto!
#
#     @ C:\Users\Admin\.julia\packages\GPUArrays\0F4Dn\src\host\broadcast.jl:44 [inlined]
#
#  [20] copy
#
#     @ C:\Users\Admin\.julia\packages\GPUArrays\0F4Dn\src\host\broadcast.jl:29 [inlined]
#
#  [21] materialize
#
#     @ .\broadcast.jl:872 [inlined]
#
#  [22] adjoint
#
#     @ C:\Users\Admin\.julia\packages\Zygote\55SqB\src\lib\broadcast.jl:86 [inlined]
#
#  [23] _pullback(__context__::Zygote.Context{false}, 588::typeof(Base.Broadcast.broadcasted), 589::typeof(-), x::CuArray{Float32, 1, CUDA.DeviceMemory}, y::Vector{Float32})
#
#     @ Zygote C:\Users\Admin\.julia\packages\ZygoteRules\CkVIK\src\adjoint.jl:67
#
#  [24] loss
#
#     @ c:\Users\Admin\Downloads\Neural_Spiking_Dynamics\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:91 [inlined]
#
#  [25] _pullback(ctx::Zygote.Context{false}, f::typeof(loss), args::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}})
#
#     @ Zygote C:\Users\Admin\.julia\packages\Zygote\55SqB\src\compiler\interface2.jl:0
#
#  [26] #61
#
#     @ c:\Users\Admin\Downloads\Neural_Spiking_Dynamics\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:96 [inlined]
#
#  [27] _pullback(::Zygote.Context{false}, ::var"#61#62", ::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, ::SciMLBase.NullParameters)
#
#     @ Zygote C:\Users\Admin\.julia\packages\Zygote\55SqB\src\compiler\interface2.jl:0
#
#  [28] pullback(::Function, ::Zygote.Context{false}, ::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, ::Vararg{Any})
#
#     @ Zygote C:\Users\Admin\.julia\packages\Zygote\55SqB\src\compiler\interface.jl:96
#
#  [29] pullback(::Function, ::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, ::SciMLBase.NullParameters)
#
#     @ Zygote C:\Users\Admin\.julia\packages\Zygote\55SqB\src\compiler\interface.jl:94
#
#  [30] withgradient(::Function, ::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, ::Vararg{Any})
#
#     @ Zygote C:\Users\Admin\.julia\packages\Zygote\55SqB\src\compiler\interface.jl:211
#
#  [31] value_and_gradient
#
#     @ C:\Users\Admin\.julia\packages\DifferentiationInterface\4n6vR\ext\DifferentiationInterfaceZygoteExt\DifferentiationInterfaceZygoteExt.jl:115 [inlined]
#
#  [32] value_and_gradient!(f::Function, grad::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, prep::DifferentiationInterface.NoGradientPrep{Nothing}, backend::AutoZygote, x::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, contexts::DifferentiationInterface.Constant{SciMLBase.NullParameters})
#
#     @ DifferentiationInterfaceZygoteExt C:\Users\Admin\.julia\packages\DifferentiationInterface\4n6vR\ext\DifferentiationInterfaceZygoteExt\DifferentiationInterfaceZygoteExt.jl:131
#
#  [33] (::OptimizationZygoteExt.var"#fg!#18"{SciMLBase.NullParameters, OptimizationFunction{true, AutoZygote, var"#61#62", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, AutoZygote})(res::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, θ::ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}})
#
#     @ OptimizationZygoteExt C:\Users\Admin\.julia\packages\OptimizationBase\R2xIG\ext\OptimizationZygoteExt.jl:53
#
#  [34] __solve(cache::OptimizationCache{Adam{Float64, Tuple{Float64, Float64}, Float64}, true, OptimizationFunction{true, AutoZygote, var"#61#62", OptimizationZygoteExt.var"#grad#16"{SciMLBase.NullParameters, OptimizationFunction{true, AutoZygote, var"#61#62", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, AutoZygote}, OptimizationZygoteExt.var"#fg!#18"{SciMLBase.NullParameters, OptimizationFunction{true, AutoZygote, var"#61#62", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, AutoZygote}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, OptimizationBase.ReInitCache{ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, SciMLBase.NullParameters}, Nothing, Nothing, Nothing, Nothing, Nothing, Bool, OptimizationOptimisers.var"#3#5", Nothing})
#
#     @ OptimizationOptimisers C:\Users\Admin\.julia\packages\OptimizationOptimisers\atr4L\src\OptimizationOptimisers.jl:83
#
#  [35] solve!(cache::OptimizationCache{Adam{Float64, Tuple{Float64, Float64}, Float64}, true, OptimizationFunction{true, AutoZygote, var"#61#62", OptimizationZygoteExt.var"#grad#16"{SciMLBase.NullParameters, OptimizationFunction{true, AutoZygote, var"#61#62", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, AutoZygote}, OptimizationZygoteExt.var"#fg!#18"{SciMLBase.NullParameters, OptimizationFunction{true, AutoZygote, var"#61#62", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, AutoZygote}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, OptimizationBase.ReInitCache{ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, SciMLBase.NullParameters}, Nothing, Nothing, Nothing, Nothing, Nothing, Bool, OptimizationOptimisers.var"#3#5", Nothing})
#
#     @ OptimizationBase C:\Users\Admin\.julia\packages\OptimizationBase\R2xIG\src\solve.jl:205
#
#  [36] solve(::OptimizationProblem{true, OptimizationFunction{true, AutoZygote, var"#61#62", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, ComponentVector{Float32, CuArray{Float32, 1, CUDA.DeviceMemory}, Tuple{Axis{(layer_1 = ViewAxis(1:32, Axis(weight = ViewAxis(1:16, ShapedAxis((16, 1))), bias = ViewAxis(17:32, Shaped1DAxis((16,))))), layer_2 = ViewAxis(33:49, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, Shaped1DAxis((1,))))))}}}, SciMLBase.NullParameters, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, @Kwargs{}}, ::Adam{Float64, Tuple{Float64, Float64}, Float64}; kwargs::@Kwargs{maxiters::Int64})
#
#     @ OptimizationBase C:\Users\Admin\.julia\packages\OptimizationBase\R2xIG\src\solve.jl:96
#
#  [37] top-level scope
#
#     @ c:\Users\Admin\Downloads\Neural_Spiking_Dynamics\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:99
