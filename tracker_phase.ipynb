# %% [markdown]
# <div style="font-family: 'Segoe UI', 'Helvetica Neue', Arial, sans-serif;
#             background-color: #f9f9f9;
#             border: 1px solid #ddd;
#             border-radius: 8px;
#             padding: 20px;
#             width: 90%;">
#
# <h2 style="color: #333; border-bottom: 2px solid #007acc; padding-bottom: 5px;">
#         Project Steps
#     </h2>
#
# <div style="font-size: 16px; color: #444; margin-bottom: 10px;">
#         <input type="checkbox" id="p1" style="margin-right: 10px; transform: scale(1.2);">
#         <label for="p1"><strong>P-1:</strong> Theory</label>
#     </div>
#
# <div style="font-size: 16px; color: #444; margin-bottom: 10px;">
#         <input type="checkbox" id="p2" style="margin-right: 10px; transform: scale(1.2);">
#         <label for="p2"><strong>P-2:</strong> Implementation and simulation in Julia</label>
#     </div>
#
# <div style="font-size: 16px; color: #444; margin-bottom: 10px;">
#         <input type="checkbox" id="p3" style="margin-right: 10px; transform: scale(1.2);">
#         <label for="p3"><strong>P-3:</strong> SciML extension with UDE</label>
#     </div>
#
# <div style="font-size: 16px; color: #444; margin-bottom: 10px;">
#         <input type="checkbox" id="p4" style="margin-right: 10px; transform: scale(1.2);">
#         <label for="p4"><strong>P-4:</strong> SciML extension with UDE + Symbolic Regress</label>
#     </div>
#
# <div style="font-size: 16px; color: #444; margin-bottom: 10px;">
#         <input type="checkbox" id="p5" style="margin-right: 10px; transform: scale(1.2);">
#         <label for="p5"><strong>P-5:</strong> SciML extension with Neural UDE</label>
#     </div>
#
# <div style="font-size: 16px; color: #444; margin-bottom: 10px;">
#         <input type="checkbox" id="p6" style="margin-right: 10px; transform: scale(1.2);">
#         <label for="p6"><strong>P-6:</strong> Comparison UDE + SR with Neural UDE</label>
#     </div>
#
# <div style="font-size: 16px; color: #444; margin-bottom: 10px;">
#         <input type="checkbox" id="p7" style="margin-right: 10px; transform: scale(1.2);">
#         <label for="p7"><strong>P-7:</strong> Final reporting and documentation</label>
#     </div>
#
# </div>
